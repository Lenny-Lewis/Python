# %%
import pypyodbc as odbc
DRIVER_NAME = 'SQL SERVER'
SERVER_NAME = 'lennox-lewis-HP-EliteBook-840-G3'
DATABASE_NAME = 'Customers'
connection_string = f"""
    DRIVER = {{{DRIVER_NAME}}};
    SERVER = {SERVER_NAME};
    DATABASE = {DATABASE_NAME};
    Trust_Connection = yes;
"""
conn = odbc.Connection(connection_string)
print(conn)
# Out:
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[6], line 11
#       4 DATABASE_NAME = 'Customers'
#       5 connection_string = f"""
#       6     DRIVER = {{{DRIVER_NAME}}};
#       7     SERVER = {SERVER_NAME};
#       8     DATABASE = {DATABASE_NAME};
#       9     Trust_Connection = yes;
#      10 """
# ---> 11 conn = odbc.Connection(connection_string)
#      12 print(conn)
#
# File ~/jupyter-env/lib/python3.12/site-packages/pypyodbc.py:2454, in Connection.__init__(self, connectString, autocommit, ansi, timeout, unicode_results, readonly, **kargs)
#    2450 if self.connection_timeout != 0:
#    2451     self.set_connection_timeout(connection_timeout)
# -> 2454 self.connect(connectString, autocommit, ansi, timeout, unicode_results, readonly)
#
# ...
