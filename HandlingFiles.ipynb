# %%
Myfile = open("//home//lennox-lewis//Desktop//Jupyter Lab//DS//mambo.txt", 'r')
print(Myfile.read())
Myfile.close()
# Out:
# We are ready to study the various file handling operations

# %%
Myfile = open("//home//lennox-lewis//Desktop//Jupyter Lab//DS//trial.txt", 'x')
Myfile.close()

# %%
Myfile = open("//home//lennox-lewis//Desktop//Jupyter Lab//DS//trial.txt", 'w')
Myfile.write("This is very interesting!")
Myfile.close()

# %%
Myfile = open("//home//lennox-lewis//Desktop//Jupyter Lab//DS//trial.txt", 'a')
Myfile.write("\n Handling files is easy!")
Myfile.close()

# %%
import os
Pathname = "//home//lennox-lewis//Desktop//Jupyter Lab//DS//mambo.txt"
current_directory = os.getcwd()
print("The current working directory is:", current_directory)
# Out:
# The current working directory is: /home/lennox-lewis/Desktop/Jupyter Lab

# %%
os.remove(Pathname)
