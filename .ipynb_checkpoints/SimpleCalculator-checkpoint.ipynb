# %%
a. Write a Python program that implements a simple command-line calculator.
The calculator should support addition, subtraction, multiplication, and division
operations. Handle input validation and error cases gracefully. (8 Marks)
b. Discuss the benefits and drawbacks of using Python's lambda functions.
Provide examples where lambda functions are useful compared to regular
function definitions. (6 Marks)
c. Explain the concept of exception handling in Python. Provide examples of
common exceptions and how to handle them using try-except blocks. (6 Marks)
